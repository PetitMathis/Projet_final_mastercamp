# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import zipfile
import json
import re
import pandas as pd
import numpy as np

BASE_DIR = "/content/drive/Shareddrives/Analyse des Avis et Alertes"
DATA_DIR = BASE_DIR + "/data"
OUTPUT_DIR = BASE_DIR + "/outputs"

ZIP_PATH = "/content/drive/MyDrive/data.zip"

print("ZIP trouvé :", os.path.exists(ZIP_PATH))
